# %%
import gevent.monkey
gevent.monkey.patch_all()

from locust import HttpUser, task
from locust.env import Environment
from locust.stats import stats_printer
from locust.runners import STATE_STOPPED, STATE_RUNNING
from locust.log import setup_logging

import gevent
import time
import random
import csv
import os
import json
import requests
from datetime import datetime
from collections import defaultdict
from gevent.lock import Semaphore
from gevent.event import Event

# ==== 全局配置 ====
ENTRY_NODES = [
    "http://yl-01.lab.uvalight.net:31113",
    "http://yl-02.lab.uvalight.net:31113",
    "http://yl-03.lab.uvalight.net:31113",
    "http://yl-06.lab.uvalight.net:31113",
]

ARCHITECTURES = ["centralized", "federated", "decentralized", "dynamic"]
FUNCTION_MAP = {
    "basic": "matrix-multiplication",
    "data_local": "image-resize"
}

TOTAL_TASKS = 2000  # 1000个请求
entry_logs = []
task_counter = 0
task_lock = Semaphore()
experiment_complete = Event()

# ==== 用户类 ====
class FaaSUser(HttpUser):
    wait_time_between_tasks = 0.1  # 任务间最小间隔
    
    def on_start(self):
        self.should_stop = False
    
    def on_stop(self):
        self.should_stop = True
    
    @task
    def call_function(self):
        global entry_logs, task_counter, experiment_complete
        
        # 检查是否应该停止
        if self.should_stop or experiment_complete.is_set():
            self.environment.runner.quit()
            return

        # 原子性地获取任务号和检查限制
        with task_lock:
            if task_counter >= TOTAL_TASKS:
                # 如果已经达到任务数量限制，就不再执行新任务
                if not experiment_complete.is_set():
                    print(f"✅ Task limit reached ({TOTAL_TASKS}), marking experiment complete")
                    experiment_complete.set()
                    self.environment.runner.quit()
                return
            
            task_counter += 1
            current_task = task_counter
            
            # 如果这是最后一个任务，标记实验即将完成
            if current_task == TOTAL_TASKS:
                print(f"🎯 Submitting final task ({TOTAL_TASKS}/{TOTAL_TASKS})")

        payload = {
            "fn_name": FUNCTION_MAP.get(os.getenv("FUNC_TYPE", "basic"), "matrix-multiplication"),
            "payload": None
        }
        if os.getenv("FUNC_TYPE") == "data_local":
            payload["payload"] = "http://yl-01.lab.uvalight.net:9000/images/image.jpg"

        entry_url = random.choice(ENTRY_NODES) + "/entry"
        selected_node = entry_url.split("//")[1].split(":")[0]  # 提取节点名
        start = time.time()

        try:
            with self.client.post(entry_url, json=payload, timeout=30, catch_response=True) as res:
                duration = time.time() - start
                timestamp = datetime.now().isoformat()
                
                if res.status_code == 200:
                    # 记录详细信息（使用锁保护）
                    with task_lock:
                        entry_logs.append({
                            "architecture": os.getenv("ARCH", "dynamic"),
                            "fn_type": os.getenv("FUNC_TYPE", "basic"),
                            "concurrency": os.getenv("CONCURRENCY", "unknown"),
                            "task_id": current_task,
                            "response_time": round(duration, 3),
                            "status": "success",
                            "timestamp": timestamp,
                            "entry_node": selected_node,
                            "real_arch": res.json().get("architecture", os.getenv("ARCH", "dynamic"))
                        })
                    res.success()
                else:
                    # 记录失败的请求（使用锁保护）
                    with task_lock:
                        entry_logs.append({
                            "architecture": os.getenv("ARCH", "dynamic"),
                            "fn_type": os.getenv("FUNC_TYPE", "basic"),
                            "concurrency": os.getenv("CONCURRENCY", "unknown"),
                            "task_id": current_task,
                            "response_time": round(duration, 3),
                            "status": f"http_{res.status_code}",
                            "timestamp": timestamp,
                            "entry_node": selected_node,
                            "real_arch": res.json().get("architecture", os.getenv("ARCH", "dynamic"))
                        })
                    res.failure(f"HTTP {res.status_code}")
        except Exception as e:
            duration = time.time() - start
            timestamp = datetime.now().isoformat()
            # 记录异常的请求（使用锁保护）
            with task_lock:
                entry_logs.append({
                    "architecture": os.getenv("ARCH", "dynamic"),
                    "fn_type": os.getenv("FUNC_TYPE", "basic"),
                    "concurrency": os.getenv("CONCURRENCY", "unknown"),
                    "task_id": current_task,
                    "response_time": round(duration, 3),
                    "status": f"exception_{type(e).__name__}",
                    "timestamp": timestamp,
                    "entry_node": selected_node
                })
            print(f"[!] Task {current_task} failed after {duration:.3f}s: {e}")
            if 'res' in locals():
                res.failure(f"Exception: {e}")
        
        # 如果这是最后一个任务完成，标记实验完成
        if current_task == TOTAL_TASKS:
            print(f"🎉 Final task completed! Marking experiment as done.")
            experiment_complete.set()
            self.environment.runner.quit()


# ==== 远程重载架构 ====
def reload_architecture(arch):
    success_count = 0
    ALL_NODES = [
        "http://yl-01.lab.uvalight.net:31113",
        "http://yl-02.lab.uvalight.net:31113",
        "http://yl-03.lab.uvalight.net:31113",
        "http://yl-04.lab.uvalight.net:31113",
        "http://yl-06.lab.uvalight.net:31113",
    ]
    for base in ALL_NODES:
        try:
            res = requests.post(base + "/reload", json={"architecture": arch}, timeout=10)
            if res.status_code == 200:
                success_count += 1
                print(f"[✓] Reloaded {base} to {arch}")
            else:
                print(f"[!] Reload failed on {base}: HTTP {res.status_code}")
        except Exception as e:
            print(f"[x] Reload error on {base}: {e}")
    
    if success_count == 0:
        raise Exception(f"Failed to reload architecture on all nodes")
    
    # 等待架构切换完成
    time.sleep(5)


# ==== 鲁棒的实验运行函数 ====
def run_experiment(host, func_type, arch, concurrency, output_csv, detailed_csv):
    global entry_logs, task_counter, experiment_complete
    
    # 重置全局状态
    entry_logs = []
    task_counter = 0
    experiment_complete.clear()

    os.environ["FUNC_TYPE"] = func_type
    os.environ["ARCH"] = arch
    os.environ["CONCURRENCY"] = str(concurrency)  # 添加并发数到环境变量

    print(f"\n🚀 Starting experiment: {arch} | {func_type} | concurrency={concurrency}")
    
    try:
        # 重载架构
        reload_architecture(arch)
        
        # 设置日志
        setup_logging("INFO", None)
        
        # 创建环境
        env = Environment(user_classes=[FaaSUser])
        env.create_local_runner()
        env.host = host
        
        # 启动统计打印器
        stats_greenlet = gevent.spawn(stats_printer, env.stats)
        
        # 记录开始时间
        start_time = time.time()
        
        # 启动测试
        env.runner.start(user_count=concurrency, spawn_rate=concurrency)
        print(f"✅ Started {concurrency} concurrent users")
        
        # 等待完成，使用多重超时机制
        max_experiment_time = max(600, TOTAL_TASKS * 2)  # 最长10分钟或每个任务2秒
        check_interval = 5  # 每5秒检查一次
        elapsed = 0
        tasks_completed_logged = False  # 防止重复日志
        
        while (not experiment_complete.is_set() and 
               env.runner.state not in [STATE_STOPPED] and
               elapsed < max_experiment_time):
            
            time.sleep(check_interval)
            elapsed = time.time() - start_time
            
            # 打印进度
            with task_lock:
                current_count = task_counter
                progress = (current_count / TOTAL_TASKS) * 100
                print(f"📊 Progress: {current_count}/{TOTAL_TASKS} ({progress:.1f}%) | "
                      f"Time: {elapsed:.1f}s | State: {env.runner.state}")
                
                # 检查是否所有任务都提交了（只记录一次）
                if current_count >= TOTAL_TASKS and not tasks_completed_logged:
                    print("🎯 All tasks submitted, waiting for completion...")
                    tasks_completed_logged = True
                    # 不在这里设置 experiment_complete，让用户任务自己设置
        
        # 停止测试
        print("🛑 Stopping experiment...")
        if env.runner.state != STATE_STOPPED:
            env.runner.stop()
        
        # 等待干净停止，但有超时
        stop_timeout = 30
        stop_start = time.time()
        while (env.runner.state != STATE_STOPPED and 
               time.time() - stop_start < stop_timeout):
            print(f"⏳ Waiting for clean stop... ({time.time() - stop_start:.1f}s)")
            time.sleep(1)
        
        if not stats_greenlet.dead:
            stats_greenlet.kill()
        
        total_duration = time.time() - start_time
        
        successful_requests = len(entry_logs)
        success_rate = (successful_requests / TOTAL_TASKS) * 100 if TOTAL_TASKS > 0 else 0
        
        print(f"📈 Results: {successful_requests}/{TOTAL_TASKS} successful ({success_rate:.1f}%)")
        print(f"⏱️  Total time: {total_duration:.2f}s")
        
        # 计算统计信息
        if entry_logs:
            response_times = [log['response_time'] for log in entry_logs]
            avg_response_time = sum(response_times) / len(response_times)
            min_response_time = min(response_times)
            max_response_time = max(response_times)
            # 计算百分位数
            sorted_times = sorted(response_times)
            p50 = sorted_times[int(len(sorted_times) * 0.5)]
            p95 = sorted_times[int(len(sorted_times) * 0.95)]
            p99 = sorted_times[int(len(sorted_times) * 0.99)]
            
            print(f"📊 Response time stats: avg={avg_response_time:.2f}s, "
                  f"min={min_response_time:.2f}s, max={max_response_time:.2f}s")
            print(f"📊 Percentiles: P50={p50:.2f}s, P95={p95:.2f}s, P99={p99:.2f}s")
        else:
            avg_response_time = min_response_time = max_response_time = p50 = p95 = p99 = 0
            print("⚠️ No successful requests recorded!")
        
        # 保存详细的每个请求数据到 detailed_csv
        print(f"💾 Saving {len(entry_logs)} request records to {detailed_csv}")
        if entry_logs:
            with open(detailed_csv, "a", newline="", encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=[
                    "architecture", "fn_type", "concurrency", "task_id", "response_time", 
                    "status", "timestamp", "entry_node", "real_arch"
                ])
                if f.tell() == 0:
                    writer.writeheader()
                
                for log in entry_logs:
                    writer.writerow(log)
            print(f"✅ Successfully saved {len(entry_logs)} detailed records")
        else:
            print("⚠️ No request data to save!")
        
        # 保存汇总数据到 output_csv
        with open(output_csv, "a", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=[
                "architecture", "fn_type", "concurrency", "total_time", 
                "successful_requests", "success_rate", "avg_response_time",
                "min_response_time", "max_response_time", "p50", "p95", "p99"
            ])
            if f.tell() == 0:
                writer.writeheader()
            writer.writerow({
                "architecture": arch,
                "fn_type": func_type,
                "concurrency": concurrency,
                "total_time": round(total_duration, 2),
                "successful_requests": successful_requests,
                "success_rate": round(success_rate, 2),
                "avg_response_time": round(avg_response_time, 2),
                "min_response_time": round(min_response_time, 2),
                "max_response_time": round(max_response_time, 2),
                "p50": round(p50, 2),
                "p95": round(p95, 2),
                "p99": round(p99, 2)
            })
        
        print(f"✅ Experiment completed: {func_type} | {arch} | "
              f"concurrency={concurrency} | duration={total_duration:.2f}s")
        
        return True
        
    except Exception as e:
        print(f"❌ Experiment failed: {e}")
        return False
    
    finally:
        # 确保清理
        try:
            if 'env' in locals() and hasattr(env, 'runner'):
                if env.runner.state != STATE_STOPPED:
                    env.runner.stop()
        except:
            pass


# ==== 主函数 ====
def main():
    output_file = "experiment_summary.csv"  # 汇总数据
    detailed_file = "experiment_details.csv"  # 每个请求的详细数据
    host = "http://dummy-host"
    
    # 备份之前的结果文件
    for file_path in [output_file, detailed_file]:
        if os.path.exists(file_path):
            backup_name = f"{file_path}.backup.{int(time.time())}"
            os.rename(file_path, backup_name)
            print(f"📁 Previous results backed up: {file_path} -> {backup_name}")
    
    failed_experiments = []
    
    # func_types = ["basic", "data_local"]
    func_types = ["data_local"]
    
    for func_type in func_types:
        print(f"\n🔥 Starting experiments for function type: {func_type}")
        print(f"Function: {FUNCTION_MAP.get(func_type, 'unknown')}")
        
        for arch in ARCHITECTURES:
            # for concurrency in [2, 4, 6, 8, 10, 12, 15, 20, 30, 40]:
            for concurrency in [20]:
                print(f"\n{'='*60}")
                print(f"🔬 Running: {func_type} | {arch} | concurrency={concurrency}")
                print(f"{'='*60}")
                
                success = run_experiment(host, func_type, arch, concurrency, output_file, detailed_file)
                
                if not success:
                    failed_experiments.append((func_type, arch, concurrency))
                    print(f"❌ Failed: {func_type} | {arch} | concurrency={concurrency}")
                
                cooldown = 30
                print(f"😴 Cooling down for {cooldown}s...")
                time.sleep(cooldown)

    print(f"\n{'='*60}")
    print("🎊 ALL EXPERIMENTS COMPLETED!")
    print(f"{'='*60}")
    
    if failed_experiments:
        print("❌ Failed experiments:")
        for func_type, arch, conc in failed_experiments:
            print(f"   - {func_type} | {arch} | concurrency={conc}")
    else:
        print("✅ All experiments completed successfully!")
    
    print(f"📊 Summary results saved to: {output_file}")
    print(f"📊 Detailed results saved to: {detailed_file}")
    
    if os.path.exists(detailed_file):
        try:
            import pandas as pd
            df = pd.read_csv(detailed_file)
            total_requests = len(df)
            successful_requests = len(df[df['status'] == 'success'])
            overall_success_rate = (successful_requests / total_requests) * 100 if total_requests > 0 else 0
            
            print(f"\n📈 Overall Statistics:")
            print(f"   Total requests: {total_requests}")
            print(f"   Successful requests: {successful_requests}")
            print(f"   Overall success rate: {overall_success_rate:.1f}%")
            
            if successful_requests > 0:
                success_df = df[df['status'] == 'success']
                avg_time = success_df['response_time'].mean()
                print(f"   Average response time: {avg_time:.3f}s")
                
                # 按函数类型分组统计
                print(f"\n📊 Statistics by function type:")
                for func_type in func_types:
                    func_df = success_df[success_df['fn_type'] == func_type]
                    if len(func_df) > 0:
                        func_avg = func_df['response_time'].mean()
                        func_count = len(func_df)
                        print(f"   {func_type}: {func_count} requests, avg={func_avg:.3f}s")
                
        except ImportError:
            print("\n💡 Install pandas to see overall statistics: pip install pandas")
        except Exception as e:
            print(f"\n⚠️ Could not calculate statistics: {e}")


if __name__ == "__main__":
    main()
# Out:
# 📁 Previous results backed up: experiment_summary.csv -> experiment_summary.csv.backup.1750738069
# 📁 Previous results backed up: experiment_details.csv -> experiment_details.csv.backup.1750738069
#
# 🔥 Starting experiments for function type: data_local
# Function: image-resize
#
# ============================================================
# 🔬 Running: data_local | centralized | concurrency=2
# ============================================================
#
# 🚀 Starting experiment: centralized | data_local | concurrency=2
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to centralized
# [2025-06-24 06:07:54,675] Lyt2023/INFO/locust.runners: Ramping to 2 users at a rate of 2.00 per second
# [2025-06-24 06:07:54,677] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 2} (2 total users)
# ✅ Started 2 concurrent users
# 📊 Progress: 6/2000 (0.3%) | Time: 5.0s | State: running
# 📊 Progress: 11/2000 (0.5%) | Time: 10.0s | State: running
# 📊 Progress: 16/2000 (0.8%) | Time: 15.0s | State: running
# 📊 Progress: 22/2000 (1.1%) | Time: 20.0s | State: running
# 📊 Progress: 28/2000 (1.4%) | Time: 25.0s | State: running
# 📊 Progress: 33/2000 (1.7%) | Time: 30.0s | State: running
# 📊 Progress: 39/2000 (1.9%) | Time: 35.1s | State: running
# 📊 Progress: 45/2000 (2.2%) | Time: 40.1s | State: running
# 📊 Progress: 52/2000 (2.6%) | Time: 45.1s | State: running
# 📊 Progress: 57/2000 (2.9%) | Time: 50.1s | State: running
# 📊 Progress: 63/2000 (3.1%) | Time: 55.1s | State: running
# 📊 Progress: 69/2000 (3.5%) | Time: 60.1s | State: running
# 📊 Progress: 75/2000 (3.8%) | Time: 65.1s | State: running
# 📊 Progress: 81/2000 (4.0%) | Time: 70.1s | State: running
# 📊 Progress: 87/2000 (4.3%) | Time: 75.1s | State: running
# 📊 Progress: 93/2000 (4.7%) | Time: 80.1s | State: running
# 📊 Progress: 99/2000 (5.0%) | Time: 85.1s | State: running
# 📊 Progress: 104/2000 (5.2%) | Time: 90.1s | State: running
# 📊 Progress: 110/2000 (5.5%) | Time: 95.1s | State: running
# 📊 Progress: 116/2000 (5.8%) | Time: 100.2s | State: running
# 📊 Progress: 121/2000 (6.0%) | Time: 105.2s | State: running
# 📊 Progress: 126/2000 (6.3%) | Time: 110.2s | State: running
# 📊 Progress: 132/2000 (6.6%) | Time: 115.2s | State: running
# 📊 Progress: 137/2000 (6.9%) | Time: 120.2s | State: running
# 📊 Progress: 142/2000 (7.1%) | Time: 125.2s | State: running
# 📊 Progress: 150/2000 (7.5%) | Time: 130.2s | State: running
# 📊 Progress: 156/2000 (7.8%) | Time: 135.2s | State: running
# 📊 Progress: 161/2000 (8.1%) | Time: 140.2s | State: running
# 📊 Progress: 167/2000 (8.3%) | Time: 145.2s | State: running
# 📊 Progress: 172/2000 (8.6%) | Time: 150.2s | State: running
# 📊 Progress: 177/2000 (8.8%) | Time: 155.3s | State: running
# 📊 Progress: 183/2000 (9.2%) | Time: 160.3s | State: running
# 📊 Progress: 189/2000 (9.4%) | Time: 165.3s | State: running
# 📊 Progress: 194/2000 (9.7%) | Time: 170.3s | State: running
# 📊 Progress: 201/2000 (10.1%) | Time: 175.3s | State: running
# 📊 Progress: 207/2000 (10.3%) | Time: 180.3s | State: running
# 📊 Progress: 212/2000 (10.6%) | Time: 185.3s | State: running
# 📊 Progress: 217/2000 (10.8%) | Time: 190.3s | State: running
# 📊 Progress: 225/2000 (11.2%) | Time: 195.3s | State: running
# 📊 Progress: 232/2000 (11.6%) | Time: 200.3s | State: running
# 📊 Progress: 240/2000 (12.0%) | Time: 205.3s | State: running
# 📊 Progress: 246/2000 (12.3%) | Time: 210.3s | State: running
# 📊 Progress: 251/2000 (12.6%) | Time: 215.3s | State: running
# 📊 Progress: 256/2000 (12.8%) | Time: 220.3s | State: running
# 📊 Progress: 263/2000 (13.2%) | Time: 225.3s | State: running
# 📊 Progress: 268/2000 (13.4%) | Time: 230.3s | State: running
# 📊 Progress: 274/2000 (13.7%) | Time: 235.3s | State: running
# 📊 Progress: 280/2000 (14.0%) | Time: 240.4s | State: running
# 📊 Progress: 286/2000 (14.3%) | Time: 245.4s | State: running
# 📊 Progress: 292/2000 (14.6%) | Time: 250.4s | State: running
# 📊 Progress: 299/2000 (14.9%) | Time: 255.4s | State: running
# 📊 Progress: 304/2000 (15.2%) | Time: 260.4s | State: running
# 📊 Progress: 310/2000 (15.5%) | Time: 265.4s | State: running
# 📊 Progress: 315/2000 (15.8%) | Time: 270.4s | State: running
# 📊 Progress: 320/2000 (16.0%) | Time: 275.4s | State: running
# 📊 Progress: 326/2000 (16.3%) | Time: 280.4s | State: running
# 📊 Progress: 332/2000 (16.6%) | Time: 285.4s | State: running
# 📊 Progress: 338/2000 (16.9%) | Time: 290.4s | State: running
# 📊 Progress: 342/2000 (17.1%) | Time: 295.4s | State: running
# 📊 Progress: 348/2000 (17.4%) | Time: 300.4s | State: running
# 📊 Progress: 353/2000 (17.6%) | Time: 305.4s | State: running
# 📊 Progress: 359/2000 (17.9%) | Time: 310.5s | State: running
# 📊 Progress: 365/2000 (18.2%) | Time: 315.5s | State: running
# 📊 Progress: 371/2000 (18.6%) | Time: 320.5s | State: running
# 📊 Progress: 377/2000 (18.9%) | Time: 325.5s | State: running
# 📊 Progress: 384/2000 (19.2%) | Time: 330.5s | State: running
# 📊 Progress: 389/2000 (19.4%) | Time: 335.5s | State: running
# 📊 Progress: 394/2000 (19.7%) | Time: 340.5s | State: running
# 📊 Progress: 400/2000 (20.0%) | Time: 345.5s | State: running
# 📊 Progress: 406/2000 (20.3%) | Time: 350.5s | State: running
# 📊 Progress: 410/2000 (20.5%) | Time: 355.5s | State: running
# 📊 Progress: 417/2000 (20.8%) | Time: 360.5s | State: running
# 📊 Progress: 422/2000 (21.1%) | Time: 365.5s | State: running
# 📊 Progress: 428/2000 (21.4%) | Time: 370.6s | State: running
# 📊 Progress: 434/2000 (21.7%) | Time: 375.6s | State: running
# 📊 Progress: 440/2000 (22.0%) | Time: 380.6s | State: running
# 📊 Progress: 445/2000 (22.2%) | Time: 385.6s | State: running
# 📊 Progress: 451/2000 (22.6%) | Time: 390.6s | State: running
# 📊 Progress: 456/2000 (22.8%) | Time: 395.6s | State: running
# 📊 Progress: 461/2000 (23.1%) | Time: 400.6s | State: running
# 📊 Progress: 466/2000 (23.3%) | Time: 405.6s | State: running
# 📊 Progress: 473/2000 (23.6%) | Time: 410.6s | State: running
# 📊 Progress: 478/2000 (23.9%) | Time: 415.6s | State: running
# 📊 Progress: 483/2000 (24.1%) | Time: 420.6s | State: running
# 📊 Progress: 489/2000 (24.4%) | Time: 425.7s | State: running
# 📊 Progress: 494/2000 (24.7%) | Time: 430.7s | State: running
# 📊 Progress: 500/2000 (25.0%) | Time: 435.7s | State: running
# 📊 Progress: 506/2000 (25.3%) | Time: 440.7s | State: running
# 📊 Progress: 513/2000 (25.7%) | Time: 445.7s | State: running
# 📊 Progress: 519/2000 (25.9%) | Time: 450.7s | State: running
# 📊 Progress: 525/2000 (26.2%) | Time: 455.7s | State: running
# 📊 Progress: 530/2000 (26.5%) | Time: 460.7s | State: running
# 📊 Progress: 536/2000 (26.8%) | Time: 465.7s | State: running
# 📊 Progress: 541/2000 (27.1%) | Time: 470.7s | State: running
# 📊 Progress: 549/2000 (27.5%) | Time: 475.7s | State: running
# 📊 Progress: 555/2000 (27.8%) | Time: 480.7s | State: running
# 📊 Progress: 562/2000 (28.1%) | Time: 485.8s | State: running
# 📊 Progress: 566/2000 (28.3%) | Time: 490.8s | State: running
# 📊 Progress: 570/2000 (28.5%) | Time: 495.8s | State: running
# 📊 Progress: 576/2000 (28.8%) | Time: 500.8s | State: running
# 📊 Progress: 581/2000 (29.0%) | Time: 505.8s | State: running
# 📊 Progress: 587/2000 (29.3%) | Time: 510.8s | State: running
# 📊 Progress: 594/2000 (29.7%) | Time: 515.8s | State: running
# 📊 Progress: 599/2000 (29.9%) | Time: 520.8s | State: running
# 📊 Progress: 606/2000 (30.3%) | Time: 525.8s | State: running
# 📊 Progress: 612/2000 (30.6%) | Time: 530.8s | State: running
# 📊 Progress: 618/2000 (30.9%) | Time: 535.8s | State: running
# 📊 Progress: 623/2000 (31.1%) | Time: 540.9s | State: running
# 📊 Progress: 629/2000 (31.4%) | Time: 545.9s | State: running
# 📊 Progress: 635/2000 (31.8%) | Time: 550.9s | State: running
# 📊 Progress: 640/2000 (32.0%) | Time: 555.9s | State: running
# 📊 Progress: 646/2000 (32.3%) | Time: 560.9s | State: running
# 📊 Progress: 651/2000 (32.6%) | Time: 565.9s | State: running
# 📊 Progress: 657/2000 (32.9%) | Time: 570.9s | State: running
# 📊 Progress: 664/2000 (33.2%) | Time: 575.9s | State: running
# 📊 Progress: 670/2000 (33.5%) | Time: 580.9s | State: running
# 📊 Progress: 677/2000 (33.9%) | Time: 585.9s | State: running
# 📊 Progress: 683/2000 (34.2%) | Time: 590.9s | State: running
# 📊 Progress: 689/2000 (34.4%) | Time: 595.9s | State: running
# 📊 Progress: 695/2000 (34.8%) | Time: 600.9s | State: running
# 📊 Progress: 700/2000 (35.0%) | Time: 606.0s | State: running
# 📊 Progress: 705/2000 (35.2%) | Time: 611.0s | State: running
# 📊 Progress: 711/2000 (35.5%) | Time: 616.0s | State: running
# 📊 Progress: 718/2000 (35.9%) | Time: 621.0s | State: running
# 📊 Progress: 723/2000 (36.1%) | Time: 626.0s | State: running
# 📊 Progress: 727/2000 (36.4%) | Time: 631.0s | State: running
# 📊 Progress: 732/2000 (36.6%) | Time: 636.0s | State: running
# 📊 Progress: 737/2000 (36.9%) | Time: 641.0s | State: running
# 📊 Progress: 743/2000 (37.1%) | Time: 646.0s | State: running
# 📊 Progress: 749/2000 (37.5%) | Time: 651.1s | State: running
# 📊 Progress: 755/2000 (37.8%) | Time: 656.1s | State: running
# 📊 Progress: 760/2000 (38.0%) | Time: 661.1s | State: running
# 📊 Progress: 767/2000 (38.4%) | Time: 666.1s | State: running
# 📊 Progress: 773/2000 (38.6%) | Time: 671.1s | State: running
# 📊 Progress: 779/2000 (39.0%) | Time: 676.1s | State: running
# 📊 Progress: 785/2000 (39.2%) | Time: 681.1s | State: running
# 📊 Progress: 791/2000 (39.6%) | Time: 686.1s | State: running
# 📊 Progress: 796/2000 (39.8%) | Time: 691.1s | State: running
# 📊 Progress: 802/2000 (40.1%) | Time: 696.1s | State: running
# 📊 Progress: 808/2000 (40.4%) | Time: 701.1s | State: running
# 📊 Progress: 813/2000 (40.6%) | Time: 706.1s | State: running
# 📊 Progress: 817/2000 (40.8%) | Time: 711.1s | State: running
# 📊 Progress: 824/2000 (41.2%) | Time: 716.2s | State: running
# 📊 Progress: 829/2000 (41.4%) | Time: 721.2s | State: running
# 📊 Progress: 835/2000 (41.8%) | Time: 726.2s | State: running
# 📊 Progress: 840/2000 (42.0%) | Time: 731.2s | State: running
# 📊 Progress: 847/2000 (42.4%) | Time: 736.2s | State: running
# 📊 Progress: 854/2000 (42.7%) | Time: 741.2s | State: running
# 📊 Progress: 860/2000 (43.0%) | Time: 746.2s | State: running
# 📊 Progress: 865/2000 (43.2%) | Time: 751.2s | State: running
# 📊 Progress: 872/2000 (43.6%) | Time: 756.2s | State: running
# 📊 Progress: 877/2000 (43.9%) | Time: 761.2s | State: running
# 📊 Progress: 882/2000 (44.1%) | Time: 766.2s | State: running
# 📊 Progress: 887/2000 (44.4%) | Time: 771.3s | State: running
# 📊 Progress: 894/2000 (44.7%) | Time: 776.3s | State: running
# 📊 Progress: 899/2000 (45.0%) | Time: 781.3s | State: running
# 📊 Progress: 904/2000 (45.2%) | Time: 786.3s | State: running
# 📊 Progress: 910/2000 (45.5%) | Time: 791.3s | State: running
# 📊 Progress: 915/2000 (45.8%) | Time: 796.3s | State: running
# 📊 Progress: 921/2000 (46.1%) | Time: 801.3s | State: running
# 📊 Progress: 926/2000 (46.3%) | Time: 806.3s | State: running
# 📊 Progress: 933/2000 (46.7%) | Time: 811.3s | State: running
# 📊 Progress: 937/2000 (46.9%) | Time: 816.3s | State: running
# 📊 Progress: 942/2000 (47.1%) | Time: 821.3s | State: running
# 📊 Progress: 948/2000 (47.4%) | Time: 826.3s | State: running
# 📊 Progress: 953/2000 (47.6%) | Time: 831.3s | State: running
# 📊 Progress: 960/2000 (48.0%) | Time: 836.3s | State: running
# 📊 Progress: 967/2000 (48.4%) | Time: 841.4s | State: running
# 📊 Progress: 973/2000 (48.6%) | Time: 846.4s | State: running
# 📊 Progress: 980/2000 (49.0%) | Time: 851.4s | State: running
# 📊 Progress: 986/2000 (49.3%) | Time: 856.4s | State: running
# 📊 Progress: 991/2000 (49.5%) | Time: 861.4s | State: running
# 📊 Progress: 997/2000 (49.9%) | Time: 866.4s | State: running
# 📊 Progress: 1002/2000 (50.1%) | Time: 871.4s | State: running
# 📊 Progress: 1007/2000 (50.3%) | Time: 876.4s | State: running
# 📊 Progress: 1013/2000 (50.6%) | Time: 881.4s | State: running
# 📊 Progress: 1018/2000 (50.9%) | Time: 886.5s | State: running
# 📊 Progress: 1024/2000 (51.2%) | Time: 891.5s | State: running
# 📊 Progress: 1030/2000 (51.5%) | Time: 896.5s | State: running
# 📊 Progress: 1036/2000 (51.8%) | Time: 901.5s | State: running
# 📊 Progress: 1040/2000 (52.0%) | Time: 906.5s | State: running
# 📊 Progress: 1047/2000 (52.3%) | Time: 911.5s | State: running
# 📊 Progress: 1053/2000 (52.6%) | Time: 916.5s | State: running
# 📊 Progress: 1060/2000 (53.0%) | Time: 921.5s | State: running
# 📊 Progress: 1066/2000 (53.3%) | Time: 926.5s | State: running
# 📊 Progress: 1071/2000 (53.5%) | Time: 931.5s | State: running
# 📊 Progress: 1076/2000 (53.8%) | Time: 936.5s | State: running
# 📊 Progress: 1082/2000 (54.1%) | Time: 941.5s | State: running
# 📊 Progress: 1088/2000 (54.4%) | Time: 946.5s | State: running
# 📊 Progress: 1094/2000 (54.7%) | Time: 951.5s | State: running
# 📊 Progress: 1099/2000 (54.9%) | Time: 956.6s | State: running
# 📊 Progress: 1103/2000 (55.1%) | Time: 961.6s | State: running
# 📊 Progress: 1109/2000 (55.5%) | Time: 966.6s | State: running
# 📊 Progress: 1115/2000 (55.8%) | Time: 971.6s | State: running
# 📊 Progress: 1120/2000 (56.0%) | Time: 976.6s | State: running
# 📊 Progress: 1126/2000 (56.3%) | Time: 981.6s | State: running
# 📊 Progress: 1132/2000 (56.6%) | Time: 986.6s | State: running
# 📊 Progress: 1138/2000 (56.9%) | Time: 991.6s | State: running
# 📊 Progress: 1145/2000 (57.2%) | Time: 996.6s | State: running
# 📊 Progress: 1150/2000 (57.5%) | Time: 1001.6s | State: running
# 📊 Progress: 1155/2000 (57.8%) | Time: 1006.6s | State: running
# 📊 Progress: 1160/2000 (58.0%) | Time: 1011.6s | State: running
# 📊 Progress: 1166/2000 (58.3%) | Time: 1016.6s | State: running
# 📊 Progress: 1172/2000 (58.6%) | Time: 1021.7s | State: running
# 📊 Progress: 1178/2000 (58.9%) | Time: 1026.7s | State: running
# 📊 Progress: 1184/2000 (59.2%) | Time: 1031.7s | State: running
# 📊 Progress: 1191/2000 (59.6%) | Time: 1036.7s | State: running
# 📊 Progress: 1197/2000 (59.9%) | Time: 1041.7s | State: running
# 📊 Progress: 1202/2000 (60.1%) | Time: 1046.7s | State: running
# 📊 Progress: 1208/2000 (60.4%) | Time: 1051.7s | State: running
# 📊 Progress: 1214/2000 (60.7%) | Time: 1056.7s | State: running
# 📊 Progress: 1221/2000 (61.1%) | Time: 1061.7s | State: running
# 📊 Progress: 1227/2000 (61.4%) | Time: 1066.7s | State: running
# 📊 Progress: 1232/2000 (61.6%) | Time: 1071.7s | State: running
# 📊 Progress: 1239/2000 (62.0%) | Time: 1076.7s | State: running
# 📊 Progress: 1244/2000 (62.2%) | Time: 1081.8s | State: running
# 📊 Progress: 1249/2000 (62.5%) | Time: 1086.8s | State: running
# 📊 Progress: 1254/2000 (62.7%) | Time: 1091.8s | State: running
# 📊 Progress: 1259/2000 (62.9%) | Time: 1096.8s | State: running
# 📊 Progress: 1266/2000 (63.3%) | Time: 1101.8s | State: running
# 📊 Progress: 1271/2000 (63.5%) | Time: 1106.8s | State: running
# 📊 Progress: 1278/2000 (63.9%) | Time: 1111.8s | State: running
# 📊 Progress: 1284/2000 (64.2%) | Time: 1116.8s | State: running
# 📊 Progress: 1289/2000 (64.5%) | Time: 1121.8s | State: running
# 📊 Progress: 1296/2000 (64.8%) | Time: 1126.8s | State: running
# 📊 Progress: 1303/2000 (65.1%) | Time: 1131.8s | State: running
# 📊 Progress: 1308/2000 (65.4%) | Time: 1136.8s | State: running
# 📊 Progress: 1313/2000 (65.6%) | Time: 1141.9s | State: running
# 📊 Progress: 1319/2000 (66.0%) | Time: 1146.9s | State: running
# 📊 Progress: 1325/2000 (66.2%) | Time: 1151.9s | State: running
# 📊 Progress: 1331/2000 (66.5%) | Time: 1156.9s | State: running
# 📊 Progress: 1336/2000 (66.8%) | Time: 1161.9s | State: running
# 📊 Progress: 1343/2000 (67.2%) | Time: 1166.9s | State: running
# 📊 Progress: 1348/2000 (67.4%) | Time: 1171.9s | State: running
# 📊 Progress: 1353/2000 (67.7%) | Time: 1176.9s | State: running
# 📊 Progress: 1359/2000 (68.0%) | Time: 1181.9s | State: running
# 📊 Progress: 1364/2000 (68.2%) | Time: 1186.9s | State: running
# 📊 Progress: 1369/2000 (68.5%) | Time: 1191.9s | State: running
# 📊 Progress: 1374/2000 (68.7%) | Time: 1196.9s | State: running
# 📊 Progress: 1380/2000 (69.0%) | Time: 1201.9s | State: running
# 📊 Progress: 1385/2000 (69.2%) | Time: 1206.9s | State: running
# 📊 Progress: 1390/2000 (69.5%) | Time: 1211.9s | State: running
# 📊 Progress: 1396/2000 (69.8%) | Time: 1216.9s | State: running
# 📊 Progress: 1400/2000 (70.0%) | Time: 1222.0s | State: running
# 📊 Progress: 1406/2000 (70.3%) | Time: 1227.0s | State: running
# 📊 Progress: 1411/2000 (70.5%) | Time: 1232.0s | State: running
# 📊 Progress: 1417/2000 (70.9%) | Time: 1237.0s | State: running
# 📊 Progress: 1423/2000 (71.2%) | Time: 1242.0s | State: running
# 📊 Progress: 1428/2000 (71.4%) | Time: 1247.0s | State: running
# 📊 Progress: 1435/2000 (71.8%) | Time: 1252.0s | State: running
# 📊 Progress: 1440/2000 (72.0%) | Time: 1257.0s | State: running
# 📊 Progress: 1446/2000 (72.3%) | Time: 1262.0s | State: running
# 📊 Progress: 1452/2000 (72.6%) | Time: 1267.0s | State: running
# 📊 Progress: 1457/2000 (72.9%) | Time: 1272.0s | State: running
# 📊 Progress: 1463/2000 (73.2%) | Time: 1277.0s | State: running
# 📊 Progress: 1469/2000 (73.5%) | Time: 1282.1s | State: running
# 📊 Progress: 1475/2000 (73.8%) | Time: 1287.1s | State: running
# 📊 Progress: 1480/2000 (74.0%) | Time: 1292.1s | State: running
# 📊 Progress: 1485/2000 (74.2%) | Time: 1297.1s | State: running
# 📊 Progress: 1491/2000 (74.6%) | Time: 1302.1s | State: running
# 📊 Progress: 1498/2000 (74.9%) | Time: 1307.1s | State: running
# 📊 Progress: 1502/2000 (75.1%) | Time: 1312.1s | State: running
# 📊 Progress: 1506/2000 (75.3%) | Time: 1317.2s | State: running
# 📊 Progress: 1512/2000 (75.6%) | Time: 1322.2s | State: running
# 📊 Progress: 1517/2000 (75.8%) | Time: 1327.2s | State: running
# 📊 Progress: 1522/2000 (76.1%) | Time: 1332.2s | State: running
# 📊 Progress: 1528/2000 (76.4%) | Time: 1337.2s | State: running
# 📊 Progress: 1534/2000 (76.7%) | Time: 1342.2s | State: running
# 📊 Progress: 1540/2000 (77.0%) | Time: 1347.2s | State: running
# 📊 Progress: 1547/2000 (77.3%) | Time: 1352.2s | State: running
# 📊 Progress: 1552/2000 (77.6%) | Time: 1357.2s | State: running
# 📊 Progress: 1557/2000 (77.8%) | Time: 1362.2s | State: running
# 📊 Progress: 1562/2000 (78.1%) | Time: 1367.2s | State: running
# 📊 Progress: 1567/2000 (78.3%) | Time: 1372.2s | State: running
# 📊 Progress: 1574/2000 (78.7%) | Time: 1377.2s | State: running
# 📊 Progress: 1579/2000 (79.0%) | Time: 1382.2s | State: running
# 📊 Progress: 1584/2000 (79.2%) | Time: 1387.2s | State: running
# 📊 Progress: 1590/2000 (79.5%) | Time: 1392.2s | State: running
# 📊 Progress: 1597/2000 (79.8%) | Time: 1397.2s | State: running
# 📊 Progress: 1602/2000 (80.1%) | Time: 1402.3s | State: running
# 📊 Progress: 1608/2000 (80.4%) | Time: 1407.3s | State: running
# 📊 Progress: 1613/2000 (80.7%) | Time: 1412.3s | State: running
# 📊 Progress: 1619/2000 (81.0%) | Time: 1417.3s | State: running
# 📊 Progress: 1624/2000 (81.2%) | Time: 1422.3s | State: running
# 📊 Progress: 1629/2000 (81.5%) | Time: 1427.3s | State: running
# 📊 Progress: 1635/2000 (81.8%) | Time: 1432.3s | State: running
# 📊 Progress: 1641/2000 (82.0%) | Time: 1437.3s | State: running
# 📊 Progress: 1649/2000 (82.5%) | Time: 1442.3s | State: running
# 📊 Progress: 1655/2000 (82.8%) | Time: 1447.3s | State: running
# 📊 Progress: 1661/2000 (83.0%) | Time: 1452.3s | State: running
# 📊 Progress: 1667/2000 (83.4%) | Time: 1457.3s | State: running
# 📊 Progress: 1672/2000 (83.6%) | Time: 1462.3s | State: running
# 📊 Progress: 1678/2000 (83.9%) | Time: 1467.3s | State: running
# 📊 Progress: 1683/2000 (84.2%) | Time: 1472.4s | State: running
# 📊 Progress: 1689/2000 (84.5%) | Time: 1477.4s | State: running
# 📊 Progress: 1695/2000 (84.8%) | Time: 1482.4s | State: running
# 📊 Progress: 1700/2000 (85.0%) | Time: 1487.4s | State: running
# 📊 Progress: 1706/2000 (85.3%) | Time: 1492.4s | State: running
# 📊 Progress: 1712/2000 (85.6%) | Time: 1497.4s | State: running
# 📊 Progress: 1718/2000 (85.9%) | Time: 1502.4s | State: running
# 📊 Progress: 1724/2000 (86.2%) | Time: 1507.4s | State: running
# 📊 Progress: 1729/2000 (86.5%) | Time: 1512.4s | State: running
# 📊 Progress: 1735/2000 (86.8%) | Time: 1517.4s | State: running
# 📊 Progress: 1742/2000 (87.1%) | Time: 1522.4s | State: running
# 📊 Progress: 1747/2000 (87.4%) | Time: 1527.5s | State: running
# 📊 Progress: 1753/2000 (87.6%) | Time: 1532.5s | State: running
# 📊 Progress: 1757/2000 (87.8%) | Time: 1537.5s | State: running
# 📊 Progress: 1764/2000 (88.2%) | Time: 1542.5s | State: running
# 📊 Progress: 1770/2000 (88.5%) | Time: 1547.5s | State: running
# 📊 Progress: 1774/2000 (88.7%) | Time: 1552.5s | State: running
# 📊 Progress: 1781/2000 (89.0%) | Time: 1557.5s | State: running
# 📊 Progress: 1786/2000 (89.3%) | Time: 1562.5s | State: running
# 📊 Progress: 1792/2000 (89.6%) | Time: 1567.5s | State: running
# 📊 Progress: 1798/2000 (89.9%) | Time: 1572.5s | State: running
# 📊 Progress: 1802/2000 (90.1%) | Time: 1577.5s | State: running
# 📊 Progress: 1809/2000 (90.5%) | Time: 1582.5s | State: running
# 📊 Progress: 1815/2000 (90.8%) | Time: 1587.6s | State: running
# 📊 Progress: 1821/2000 (91.0%) | Time: 1592.6s | State: running
# 📊 Progress: 1826/2000 (91.3%) | Time: 1597.6s | State: running
# 📊 Progress: 1832/2000 (91.6%) | Time: 1602.6s | State: running
# 📊 Progress: 1838/2000 (91.9%) | Time: 1607.6s | State: running
# 📊 Progress: 1845/2000 (92.2%) | Time: 1612.6s | State: running
# 📊 Progress: 1849/2000 (92.5%) | Time: 1617.6s | State: running
# 📊 Progress: 1855/2000 (92.8%) | Time: 1622.6s | State: running
# 📊 Progress: 1862/2000 (93.1%) | Time: 1627.6s | State: running
# 📊 Progress: 1867/2000 (93.3%) | Time: 1632.6s | State: running
# 📊 Progress: 1872/2000 (93.6%) | Time: 1637.6s | State: running
# 📊 Progress: 1878/2000 (93.9%) | Time: 1642.6s | State: running
# 📊 Progress: 1882/2000 (94.1%) | Time: 1647.7s | State: running
# 📊 Progress: 1889/2000 (94.5%) | Time: 1652.7s | State: running
# 📊 Progress: 1894/2000 (94.7%) | Time: 1657.7s | State: running
# 📊 Progress: 1899/2000 (95.0%) | Time: 1662.7s | State: running
# 📊 Progress: 1905/2000 (95.2%) | Time: 1667.7s | State: running
# 📊 Progress: 1912/2000 (95.6%) | Time: 1672.7s | State: running
# 📊 Progress: 1918/2000 (95.9%) | Time: 1677.7s | State: running
# 📊 Progress: 1925/2000 (96.2%) | Time: 1682.7s | State: running
# 📊 Progress: 1931/2000 (96.5%) | Time: 1687.7s | State: running
# 📊 Progress: 1936/2000 (96.8%) | Time: 1692.8s | State: running
# 📊 Progress: 1941/2000 (97.0%) | Time: 1697.8s | State: running
# 📊 Progress: 1946/2000 (97.3%) | Time: 1702.8s | State: running
# 📊 Progress: 1952/2000 (97.6%) | Time: 1707.8s | State: running
# 📊 Progress: 1957/2000 (97.9%) | Time: 1712.8s | State: running
# 📊 Progress: 1962/2000 (98.1%) | Time: 1717.8s | State: running
# 📊 Progress: 1969/2000 (98.5%) | Time: 1722.8s | State: running
# 📊 Progress: 1976/2000 (98.8%) | Time: 1727.8s | State: running
# 📊 Progress: 1982/2000 (99.1%) | Time: 1732.8s | State: running
# 📊 Progress: 1989/2000 (99.5%) | Time: 1737.8s | State: running
# 📊 Progress: 1995/2000 (99.8%) | Time: 1742.8s | State: running
# 🎯 Submitting final task (2000/2000)
# 📊 Progress: 2000/2000 (100.0%) | Time: 1747.8s | State: running
# 🎯 All tasks submitted, waiting for completion...
# 🎉 Final task completed! Marking experiment as done.
# 📊 Progress: 2000/2000 (100.0%) | Time: 1752.9s | State: stopped
# 🛑 Stopping experiment...
# 📈 Results: 2000/2000 successful (100.0%)
# ⏱️  Total time: 1752.85s
# 📊 Response time stats: avg=1.75s, min=1.15s, max=3.54s
# 📊 Percentiles: P50=1.51s, P95=2.64s, P99=2.74s
# 💾 Saving 2000 request records to experiment_details.csv
# ✅ Successfully saved 2000 detailed records
# ✅ Experiment completed: data_local | centralized | concurrency=2 | duration=1752.85s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | centralized | concurrency=4
# ============================================================
#
# 🚀 Starting experiment: centralized | data_local | concurrency=4
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to centralized
# [2025-06-24 06:37:43,040] Lyt2023/INFO/locust.runners: Ramping to 4 users at a rate of 4.00 per second
# [2025-06-24 06:37:43,041] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 4} (4 total users)
# ✅ Started 4 concurrent users
# 📊 Progress: 13/2000 (0.7%) | Time: 5.0s | State: running
# 📊 Progress: 26/2000 (1.3%) | Time: 10.0s | State: running
# 📊 Progress: 37/2000 (1.8%) | Time: 15.0s | State: running
# 📊 Progress: 49/2000 (2.5%) | Time: 20.0s | State: running
# 📊 Progress: 60/2000 (3.0%) | Time: 25.0s | State: running
# 📊 Progress: 73/2000 (3.6%) | Time: 30.0s | State: running
# 📊 Progress: 84/2000 (4.2%) | Time: 35.0s | State: running
# 📊 Progress: 96/2000 (4.8%) | Time: 40.1s | State: running
# 📊 Progress: 106/2000 (5.3%) | Time: 45.1s | State: running
# 📊 Progress: 116/2000 (5.8%) | Time: 50.1s | State: running
# 📊 Progress: 126/2000 (6.3%) | Time: 55.1s | State: running
# 📊 Progress: 137/2000 (6.9%) | Time: 60.1s | State: running
# 📊 Progress: 148/2000 (7.4%) | Time: 65.1s | State: running
# 📊 Progress: 160/2000 (8.0%) | Time: 70.1s | State: running
# 📊 Progress: 171/2000 (8.6%) | Time: 75.1s | State: running
# 📊 Progress: 183/2000 (9.2%) | Time: 80.1s | State: running
# 📊 Progress: 194/2000 (9.7%) | Time: 85.1s | State: running
# 📊 Progress: 204/2000 (10.2%) | Time: 90.1s | State: running
# 📊 Progress: 217/2000 (10.8%) | Time: 95.1s | State: running
# 📊 Progress: 229/2000 (11.5%) | Time: 100.2s | State: running
# 📊 Progress: 240/2000 (12.0%) | Time: 105.2s | State: running
# 📊 Progress: 251/2000 (12.6%) | Time: 110.2s | State: running
# 📊 Progress: 263/2000 (13.2%) | Time: 115.2s | State: running
# 📊 Progress: 275/2000 (13.8%) | Time: 120.2s | State: running
# 📊 Progress: 286/2000 (14.3%) | Time: 125.2s | State: running
# 📊 Progress: 298/2000 (14.9%) | Time: 130.2s | State: running
# 📊 Progress: 310/2000 (15.5%) | Time: 135.2s | State: running
# 📊 Progress: 320/2000 (16.0%) | Time: 140.2s | State: running
# 📊 Progress: 333/2000 (16.7%) | Time: 145.2s | State: running
# 📊 Progress: 344/2000 (17.2%) | Time: 150.2s | State: running
# 📊 Progress: 355/2000 (17.8%) | Time: 155.3s | State: running
# 📊 Progress: 366/2000 (18.3%) | Time: 160.3s | State: running
# 📊 Progress: 377/2000 (18.9%) | Time: 165.3s | State: running
# 📊 Progress: 389/2000 (19.4%) | Time: 170.3s | State: running
# 📊 Progress: 400/2000 (20.0%) | Time: 175.3s | State: running
# 📊 Progress: 412/2000 (20.6%) | Time: 180.3s | State: running
# 📊 Progress: 424/2000 (21.2%) | Time: 185.3s | State: running
# 📊 Progress: 436/2000 (21.8%) | Time: 190.3s | State: running
# 📊 Progress: 449/2000 (22.4%) | Time: 195.3s | State: running
# 📊 Progress: 459/2000 (22.9%) | Time: 200.3s | State: running
# 📊 Progress: 471/2000 (23.5%) | Time: 205.4s | State: running
# 📊 Progress: 481/2000 (24.1%) | Time: 210.4s | State: running
# 📊 Progress: 493/2000 (24.6%) | Time: 215.4s | State: running
# 📊 Progress: 505/2000 (25.2%) | Time: 220.4s | State: running
# 📊 Progress: 516/2000 (25.8%) | Time: 225.4s | State: running
# 📊 Progress: 526/2000 (26.3%) | Time: 230.4s | State: running
# 📊 Progress: 539/2000 (27.0%) | Time: 235.4s | State: running
# 📊 Progress: 549/2000 (27.5%) | Time: 240.4s | State: running
# 📊 Progress: 561/2000 (28.1%) | Time: 245.4s | State: running
# 📊 Progress: 575/2000 (28.7%) | Time: 250.4s | State: running
# 📊 Progress: 587/2000 (29.3%) | Time: 255.5s | State: running
# 📊 Progress: 598/2000 (29.9%) | Time: 260.5s | State: running
# 📊 Progress: 610/2000 (30.5%) | Time: 265.5s | State: running
# 📊 Progress: 621/2000 (31.1%) | Time: 270.5s | State: running
# 📊 Progress: 634/2000 (31.7%) | Time: 275.5s | State: running
# 📊 Progress: 646/2000 (32.3%) | Time: 280.5s | State: running
# 📊 Progress: 655/2000 (32.8%) | Time: 285.5s | State: running
# 📊 Progress: 666/2000 (33.3%) | Time: 290.5s | State: running
# 📊 Progress: 679/2000 (34.0%) | Time: 295.5s | State: running
# 📊 Progress: 689/2000 (34.4%) | Time: 300.5s | State: running
# 📊 Progress: 699/2000 (34.9%) | Time: 305.5s | State: running
# 📊 Progress: 712/2000 (35.6%) | Time: 310.5s | State: running
# 📊 Progress: 722/2000 (36.1%) | Time: 315.5s | State: running
# 📊 Progress: 732/2000 (36.6%) | Time: 320.5s | State: running
# 📊 Progress: 743/2000 (37.1%) | Time: 325.6s | State: running
# 📊 Progress: 754/2000 (37.7%) | Time: 330.6s | State: running
# 📊 Progress: 766/2000 (38.3%) | Time: 335.6s | State: running
# 📊 Progress: 777/2000 (38.9%) | Time: 340.6s | State: running
# 📊 Progress: 790/2000 (39.5%) | Time: 345.6s | State: running
# 📊 Progress: 801/2000 (40.1%) | Time: 350.6s | State: running
# 📊 Progress: 815/2000 (40.8%) | Time: 355.6s | State: running
# 📊 Progress: 827/2000 (41.3%) | Time: 360.6s | State: running
# 📊 Progress: 837/2000 (41.9%) | Time: 365.6s | State: running
# 📊 Progress: 848/2000 (42.4%) | Time: 370.6s | State: running
# 📊 Progress: 858/2000 (42.9%) | Time: 375.7s | State: running
# 📊 Progress: 868/2000 (43.4%) | Time: 380.7s | State: running
# 📊 Progress: 877/2000 (43.9%) | Time: 385.7s | State: running
# 📊 Progress: 888/2000 (44.4%) | Time: 390.7s | State: running
# 📊 Progress: 901/2000 (45.1%) | Time: 395.7s | State: running
# 📊 Progress: 912/2000 (45.6%) | Time: 400.7s | State: running
# 📊 Progress: 923/2000 (46.2%) | Time: 405.7s | State: running
# 📊 Progress: 934/2000 (46.7%) | Time: 410.7s | State: running
# 📊 Progress: 945/2000 (47.2%) | Time: 415.7s | State: running
# 📊 Progress: 956/2000 (47.8%) | Time: 420.7s | State: running
# 📊 Progress: 969/2000 (48.4%) | Time: 425.7s | State: running
# 📊 Progress: 981/2000 (49.0%) | Time: 430.7s | State: running
# 📊 Progress: 993/2000 (49.6%) | Time: 435.7s | State: running
# 📊 Progress: 1005/2000 (50.2%) | Time: 440.7s | State: running
# 📊 Progress: 1018/2000 (50.9%) | Time: 445.7s | State: running
# 📊 Progress: 1028/2000 (51.4%) | Time: 450.8s | State: running
# 📊 Progress: 1039/2000 (51.9%) | Time: 455.8s | State: running
# 📊 Progress: 1051/2000 (52.5%) | Time: 460.8s | State: running
# 📊 Progress: 1062/2000 (53.1%) | Time: 465.8s | State: running
# 📊 Progress: 1073/2000 (53.6%) | Time: 470.8s | State: running
# 📊 Progress: 1083/2000 (54.1%) | Time: 475.8s | State: running
# 📊 Progress: 1094/2000 (54.7%) | Time: 480.8s | State: running
# 📊 Progress: 1105/2000 (55.2%) | Time: 485.8s | State: running
# 📊 Progress: 1117/2000 (55.9%) | Time: 490.8s | State: running
# 📊 Progress: 1128/2000 (56.4%) | Time: 495.8s | State: running
# 📊 Progress: 1138/2000 (56.9%) | Time: 500.8s | State: running
# 📊 Progress: 1149/2000 (57.5%) | Time: 505.8s | State: running
# 📊 Progress: 1160/2000 (58.0%) | Time: 510.8s | State: running
# 📊 Progress: 1171/2000 (58.6%) | Time: 515.8s | State: running
# 📊 Progress: 1183/2000 (59.2%) | Time: 520.8s | State: running
# 📊 Progress: 1193/2000 (59.7%) | Time: 525.8s | State: running
# 📊 Progress: 1204/2000 (60.2%) | Time: 530.8s | State: running
# 📊 Progress: 1216/2000 (60.8%) | Time: 535.9s | State: running
# 📊 Progress: 1226/2000 (61.3%) | Time: 540.9s | State: running
# 📊 Progress: 1238/2000 (61.9%) | Time: 545.9s | State: running
# 📊 Progress: 1249/2000 (62.5%) | Time: 550.9s | State: running
# 📊 Progress: 1260/2000 (63.0%) | Time: 555.9s | State: running
# 📊 Progress: 1272/2000 (63.6%) | Time: 560.9s | State: running
# 📊 Progress: 1283/2000 (64.1%) | Time: 565.9s | State: running
# 📊 Progress: 1296/2000 (64.8%) | Time: 570.9s | State: running
# 📊 Progress: 1307/2000 (65.3%) | Time: 575.9s | State: running
# 📊 Progress: 1320/2000 (66.0%) | Time: 580.9s | State: running
# 📊 Progress: 1331/2000 (66.5%) | Time: 585.9s | State: running
# 📊 Progress: 1342/2000 (67.1%) | Time: 590.9s | State: running
# 📊 Progress: 1354/2000 (67.7%) | Time: 595.9s | State: running
# 📊 Progress: 1367/2000 (68.3%) | Time: 600.9s | State: running
# 📊 Progress: 1378/2000 (68.9%) | Time: 606.0s | State: running
# 📊 Progress: 1389/2000 (69.5%) | Time: 611.0s | State: running
# 📊 Progress: 1401/2000 (70.0%) | Time: 616.0s | State: running
# 📊 Progress: 1412/2000 (70.6%) | Time: 621.0s | State: running
# 📊 Progress: 1423/2000 (71.2%) | Time: 626.0s | State: running
# 📊 Progress: 1435/2000 (71.8%) | Time: 631.0s | State: running
# 📊 Progress: 1449/2000 (72.5%) | Time: 636.0s | State: running
# 📊 Progress: 1458/2000 (72.9%) | Time: 641.0s | State: running
# 📊 Progress: 1470/2000 (73.5%) | Time: 646.0s | State: running
# 📊 Progress: 1481/2000 (74.1%) | Time: 651.0s | State: running
# 📊 Progress: 1493/2000 (74.7%) | Time: 656.0s | State: running
# 📊 Progress: 1505/2000 (75.2%) | Time: 661.0s | State: running
# 📊 Progress: 1518/2000 (75.9%) | Time: 666.1s | State: running
# 📊 Progress: 1528/2000 (76.4%) | Time: 671.1s | State: running
# 📊 Progress: 1539/2000 (77.0%) | Time: 676.1s | State: running
# 📊 Progress: 1550/2000 (77.5%) | Time: 681.1s | State: running
# 📊 Progress: 1562/2000 (78.1%) | Time: 686.1s | State: running
# 📊 Progress: 1572/2000 (78.6%) | Time: 691.1s | State: running
# 📊 Progress: 1583/2000 (79.1%) | Time: 696.1s | State: running
# 📊 Progress: 1595/2000 (79.8%) | Time: 701.1s | State: running
# 📊 Progress: 1606/2000 (80.3%) | Time: 706.1s | State: running
# 📊 Progress: 1618/2000 (80.9%) | Time: 711.1s | State: running
# 📊 Progress: 1628/2000 (81.4%) | Time: 716.1s | State: running
# 📊 Progress: 1639/2000 (82.0%) | Time: 721.1s | State: running
# 📊 Progress: 1651/2000 (82.5%) | Time: 726.1s | State: running
# 📊 Progress: 1660/2000 (83.0%) | Time: 731.2s | State: running
# 📊 Progress: 1672/2000 (83.6%) | Time: 736.2s | State: running
# 📊 Progress: 1681/2000 (84.0%) | Time: 741.2s | State: running
# 📊 Progress: 1695/2000 (84.8%) | Time: 746.2s | State: running
# 📊 Progress: 1707/2000 (85.4%) | Time: 751.2s | State: running
# 📊 Progress: 1720/2000 (86.0%) | Time: 756.2s | State: running
# 📊 Progress: 1730/2000 (86.5%) | Time: 761.2s | State: running
# 📊 Progress: 1742/2000 (87.1%) | Time: 766.3s | State: running
# 📊 Progress: 1753/2000 (87.6%) | Time: 771.3s | State: running
# 📊 Progress: 1765/2000 (88.2%) | Time: 776.3s | State: running
# 📊 Progress: 1777/2000 (88.8%) | Time: 781.3s | State: running
# 📊 Progress: 1787/2000 (89.3%) | Time: 786.3s | State: running
# 📊 Progress: 1799/2000 (90.0%) | Time: 791.3s | State: running
# 📊 Progress: 1810/2000 (90.5%) | Time: 796.3s | State: running
# 📊 Progress: 1821/2000 (91.0%) | Time: 801.3s | State: running
# 📊 Progress: 1831/2000 (91.5%) | Time: 806.3s | State: running
# 📊 Progress: 1843/2000 (92.2%) | Time: 811.3s | State: running
# 📊 Progress: 1853/2000 (92.7%) | Time: 816.3s | State: running
# 📊 Progress: 1865/2000 (93.2%) | Time: 821.3s | State: running
# 📊 Progress: 1875/2000 (93.8%) | Time: 826.3s | State: running
# 📊 Progress: 1888/2000 (94.4%) | Time: 831.3s | State: running
# 📊 Progress: 1900/2000 (95.0%) | Time: 836.3s | State: running
# 📊 Progress: 1911/2000 (95.5%) | Time: 841.3s | State: running
# 📊 Progress: 1924/2000 (96.2%) | Time: 846.3s | State: running
# 📊 Progress: 1936/2000 (96.8%) | Time: 851.3s | State: running
# 📊 Progress: 1947/2000 (97.4%) | Time: 856.4s | State: running
# 📊 Progress: 1958/2000 (97.9%) | Time: 861.4s | State: running
# 📊 Progress: 1970/2000 (98.5%) | Time: 866.4s | State: running
# 📊 Progress: 1982/2000 (99.1%) | Time: 871.4s | State: running
# 📊 Progress: 1995/2000 (99.8%) | Time: 876.4s | State: running
# 🎯 Submitting final task (2000/2000)
# ✅ Task limit reached (2000), marking experiment complete
# 📊 Progress: 2000/2000 (100.0%) | Time: 881.4s | State: cleanup
# 🎯 All tasks submitted, waiting for completion...
# 🛑 Stopping experiment...
# 📈 Results: 1997/2000 successful (99.9%)
# ⏱️  Total time: 881.44s
# 📊 Response time stats: avg=1.76s, min=1.14s, max=4.49s
# 📊 Percentiles: P50=1.53s, P95=2.64s, P99=2.74s
# 💾 Saving 1997 request records to experiment_details.csv
# ✅ Successfully saved 1997 detailed records
# ✅ Experiment completed: data_local | centralized | concurrency=4 | duration=881.44s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | centralized | concurrency=6
# ============================================================
#
# 🚀 Starting experiment: centralized | data_local | concurrency=6
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to centralized
# [2025-06-24 06:52:59,991] Lyt2023/INFO/locust.runners: Ramping to 6 users at a rate of 6.00 per second
# [2025-06-24 06:52:59,993] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 6} (6 total users)
# ✅ Started 6 concurrent users
# 📊 Progress: 20/2000 (1.0%) | Time: 5.0s | State: running
# 📊 Progress: 36/2000 (1.8%) | Time: 10.0s | State: running
# 📊 Progress: 53/2000 (2.6%) | Time: 15.0s | State: running
# 📊 Progress: 71/2000 (3.5%) | Time: 20.0s | State: running
# 📊 Progress: 89/2000 (4.5%) | Time: 25.0s | State: running
# 📊 Progress: 109/2000 (5.5%) | Time: 30.0s | State: running
# 📊 Progress: 125/2000 (6.2%) | Time: 35.0s | State: running
# 📊 Progress: 139/2000 (7.0%) | Time: 40.1s | State: running
# 📊 Progress: 157/2000 (7.8%) | Time: 45.1s | State: running
# 📊 Progress: 178/2000 (8.9%) | Time: 50.1s | State: running
# 📊 Progress: 192/2000 (9.6%) | Time: 55.1s | State: running
# 📊 Progress: 209/2000 (10.4%) | Time: 60.1s | State: running
# 📊 Progress: 226/2000 (11.3%) | Time: 65.1s | State: running
# 📊 Progress: 242/2000 (12.1%) | Time: 70.1s | State: running
# 📊 Progress: 258/2000 (12.9%) | Time: 75.1s | State: running
# 📊 Progress: 275/2000 (13.8%) | Time: 80.1s | State: running
# 📊 Progress: 294/2000 (14.7%) | Time: 85.1s | State: running
# 📊 Progress: 312/2000 (15.6%) | Time: 90.1s | State: running
# 📊 Progress: 329/2000 (16.4%) | Time: 95.1s | State: running
# 📊 Progress: 347/2000 (17.3%) | Time: 100.1s | State: running
# 📊 Progress: 364/2000 (18.2%) | Time: 105.1s | State: running
# 📊 Progress: 381/2000 (19.1%) | Time: 110.2s | State: running
# 📊 Progress: 398/2000 (19.9%) | Time: 115.2s | State: running
# 📊 Progress: 415/2000 (20.8%) | Time: 120.2s | State: running
# 📊 Progress: 431/2000 (21.6%) | Time: 125.2s | State: running
# 📊 Progress: 448/2000 (22.4%) | Time: 130.2s | State: running
# 📊 Progress: 463/2000 (23.2%) | Time: 135.2s | State: running
# 📊 Progress: 481/2000 (24.1%) | Time: 140.2s | State: running
# 📊 Progress: 500/2000 (25.0%) | Time: 145.2s | State: running
# 📊 Progress: 515/2000 (25.8%) | Time: 150.2s | State: running
# 📊 Progress: 532/2000 (26.6%) | Time: 155.2s | State: running
# 📊 Progress: 549/2000 (27.5%) | Time: 160.2s | State: running
# 📊 Progress: 561/2000 (28.1%) | Time: 165.2s | State: running
# 📊 Progress: 581/2000 (29.0%) | Time: 170.3s | State: running
# 📊 Progress: 598/2000 (29.9%) | Time: 175.3s | State: running
# 📊 Progress: 615/2000 (30.8%) | Time: 180.3s | State: running
# 📊 Progress: 631/2000 (31.6%) | Time: 185.3s | State: running
# 📊 Progress: 648/2000 (32.4%) | Time: 190.3s | State: running
# 📊 Progress: 667/2000 (33.4%) | Time: 195.3s | State: running
# 📊 Progress: 686/2000 (34.3%) | Time: 200.3s | State: running
# 📊 Progress: 704/2000 (35.2%) | Time: 205.3s | State: running
# 📊 Progress: 723/2000 (36.1%) | Time: 210.3s | State: running
# 📊 Progress: 739/2000 (37.0%) | Time: 215.3s | State: running
# 📊 Progress: 756/2000 (37.8%) | Time: 220.3s | State: running
# 📊 Progress: 773/2000 (38.6%) | Time: 225.3s | State: running
# 📊 Progress: 790/2000 (39.5%) | Time: 230.3s | State: running
# 📊 Progress: 806/2000 (40.3%) | Time: 235.3s | State: running
# 📊 Progress: 822/2000 (41.1%) | Time: 240.4s | State: running
# 📊 Progress: 840/2000 (42.0%) | Time: 245.4s | State: running
# 📊 Progress: 856/2000 (42.8%) | Time: 250.4s | State: running
# 📊 Progress: 871/2000 (43.5%) | Time: 255.4s | State: running
# 📊 Progress: 890/2000 (44.5%) | Time: 260.4s | State: running
# 📊 Progress: 908/2000 (45.4%) | Time: 265.4s | State: running
# 📊 Progress: 926/2000 (46.3%) | Time: 270.4s | State: running
# 📊 Progress: 945/2000 (47.2%) | Time: 275.4s | State: running
# 📊 Progress: 958/2000 (47.9%) | Time: 280.4s | State: running
# 📊 Progress: 977/2000 (48.9%) | Time: 285.4s | State: running
# 📊 Progress: 996/2000 (49.8%) | Time: 290.4s | State: running
# 📊 Progress: 1011/2000 (50.5%) | Time: 295.4s | State: running
# 📊 Progress: 1028/2000 (51.4%) | Time: 300.4s | State: running
# 📊 Progress: 1043/2000 (52.1%) | Time: 305.4s | State: running
# 📊 Progress: 1061/2000 (53.0%) | Time: 310.4s | State: running
# 📊 Progress: 1080/2000 (54.0%) | Time: 315.5s | State: running
# 📊 Progress: 1096/2000 (54.8%) | Time: 320.5s | State: running
# 📊 Progress: 1114/2000 (55.7%) | Time: 325.5s | State: running
# 📊 Progress: 1133/2000 (56.6%) | Time: 330.5s | State: running
# 📊 Progress: 1151/2000 (57.6%) | Time: 335.5s | State: running
# 📊 Progress: 1166/2000 (58.3%) | Time: 340.5s | State: running
# 📊 Progress: 1184/2000 (59.2%) | Time: 345.5s | State: running
# 📊 Progress: 1199/2000 (60.0%) | Time: 350.5s | State: running
# 📊 Progress: 1217/2000 (60.9%) | Time: 355.5s | State: running
# 📊 Progress: 1233/2000 (61.7%) | Time: 360.5s | State: running
# 📊 Progress: 1251/2000 (62.5%) | Time: 365.5s | State: running
# 📊 Progress: 1266/2000 (63.3%) | Time: 370.6s | State: running
# 📊 Progress: 1283/2000 (64.1%) | Time: 375.6s | State: running
# 📊 Progress: 1302/2000 (65.1%) | Time: 380.6s | State: running
# 📊 Progress: 1316/2000 (65.8%) | Time: 385.6s | State: running
# 📊 Progress: 1334/2000 (66.7%) | Time: 390.6s | State: running
# 📊 Progress: 1351/2000 (67.5%) | Time: 395.6s | State: running
# 📊 Progress: 1368/2000 (68.4%) | Time: 400.6s | State: running
# 📊 Progress: 1386/2000 (69.3%) | Time: 405.6s | State: running
# 📊 Progress: 1403/2000 (70.2%) | Time: 410.6s | State: running
# 📊 Progress: 1420/2000 (71.0%) | Time: 415.6s | State: running
# 📊 Progress: 1438/2000 (71.9%) | Time: 420.6s | State: running
# 📊 Progress: 1453/2000 (72.7%) | Time: 425.6s | State: running
# 📊 Progress: 1469/2000 (73.5%) | Time: 430.6s | State: running
# 📊 Progress: 1488/2000 (74.4%) | Time: 435.6s | State: running
# 📊 Progress: 1504/2000 (75.2%) | Time: 440.6s | State: running
# 📊 Progress: 1523/2000 (76.1%) | Time: 445.6s | State: running
# 📊 Progress: 1538/2000 (76.9%) | Time: 450.6s | State: running
# 📊 Progress: 1556/2000 (77.8%) | Time: 455.7s | State: running
# 📊 Progress: 1572/2000 (78.6%) | Time: 460.7s | State: running
# 📊 Progress: 1587/2000 (79.3%) | Time: 465.7s | State: running
# 📊 Progress: 1600/2000 (80.0%) | Time: 470.7s | State: running
# 📊 Progress: 1619/2000 (81.0%) | Time: 475.7s | State: running
# 📊 Progress: 1636/2000 (81.8%) | Time: 480.7s | State: running
# 📊 Progress: 1653/2000 (82.7%) | Time: 485.7s | State: running
# 📊 Progress: 1671/2000 (83.5%) | Time: 490.7s | State: running
# 📊 Progress: 1688/2000 (84.4%) | Time: 495.7s | State: running
# 📊 Progress: 1704/2000 (85.2%) | Time: 500.7s | State: running
# 📊 Progress: 1718/2000 (85.9%) | Time: 505.7s | State: running
# 📊 Progress: 1734/2000 (86.7%) | Time: 510.7s | State: running
# 📊 Progress: 1752/2000 (87.6%) | Time: 515.7s | State: running
# 📊 Progress: 1769/2000 (88.4%) | Time: 520.7s | State: running
# 📊 Progress: 1784/2000 (89.2%) | Time: 525.8s | State: running
# 📊 Progress: 1799/2000 (90.0%) | Time: 530.8s | State: running
# 📊 Progress: 1818/2000 (90.9%) | Time: 535.8s | State: running
# 📊 Progress: 1831/2000 (91.5%) | Time: 540.8s | State: running
# 📊 Progress: 1852/2000 (92.6%) | Time: 545.8s | State: running
# 📊 Progress: 1869/2000 (93.5%) | Time: 550.8s | State: running
# 📊 Progress: 1884/2000 (94.2%) | Time: 555.8s | State: running
# 📊 Progress: 1904/2000 (95.2%) | Time: 560.8s | State: running
# 📊 Progress: 1919/2000 (96.0%) | Time: 565.8s | State: running
# 📊 Progress: 1934/2000 (96.7%) | Time: 570.8s | State: running
# 📊 Progress: 1951/2000 (97.5%) | Time: 575.8s | State: running
# 📊 Progress: 1968/2000 (98.4%) | Time: 580.8s | State: running
# 📊 Progress: 1986/2000 (99.3%) | Time: 585.8s | State: running
# 🎯 Submitting final task (2000/2000)
# ✅ Task limit reached (2000), marking experiment complete
# 📊 Progress: 2000/2000 (100.0%) | Time: 590.9s | State: cleanup
# 🎯 All tasks submitted, waiting for completion...
# 🛑 Stopping experiment...
# 📈 Results: 1995/2000 successful (99.8%)
# ⏱️  Total time: 590.88s
# 📊 Response time stats: avg=1.77s, min=1.14s, max=5.97s
# 📊 Percentiles: P50=1.54s, P95=2.65s, P99=2.83s
# 💾 Saving 1995 request records to experiment_details.csv
# ✅ Successfully saved 1995 detailed records
# ✅ Experiment completed: data_local | centralized | concurrency=6 | duration=590.88s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | centralized | concurrency=8
# ============================================================
#
# 🚀 Starting experiment: centralized | data_local | concurrency=8
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to centralized
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to centralized
# [2025-06-24 07:03:26,366] Lyt2023/INFO/locust.runners: Ramping to 8 users at a rate of 8.00 per second
# [2025-06-24 07:03:26,367] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 8} (8 total users)
# ✅ Started 8 concurrent users
# 📊 Progress: 26/2000 (1.3%) | Time: 5.0s | State: running
# 📊 Progress: 48/2000 (2.4%) | Time: 10.0s | State: running
# 📊 Progress: 68/2000 (3.4%) | Time: 15.0s | State: running
# 📊 Progress: 90/2000 (4.5%) | Time: 20.0s | State: running
# 📊 Progress: 113/2000 (5.7%) | Time: 25.0s | State: running
# 📊 Progress: 138/2000 (6.9%) | Time: 30.1s | State: running
# 📊 Progress: 160/2000 (8.0%) | Time: 35.1s | State: running
# 📊 Progress: 183/2000 (9.2%) | Time: 40.1s | State: running
# 📊 Progress: 206/2000 (10.3%) | Time: 45.1s | State: running
# 📊 Progress: 228/2000 (11.4%) | Time: 50.1s | State: running
# 📊 Progress: 251/2000 (12.6%) | Time: 55.1s | State: running
# 📊 Progress: 274/2000 (13.7%) | Time: 60.1s | State: running
# 📊 Progress: 295/2000 (14.8%) | Time: 65.1s | State: running
# 📊 Progress: 321/2000 (16.1%) | Time: 70.1s | State: running
# 📊 Progress: 341/2000 (17.1%) | Time: 75.2s | State: running
# 📊 Progress: 360/2000 (18.0%) | Time: 80.2s | State: running
# 📊 Progress: 385/2000 (19.2%) | Time: 85.2s | State: running
# 📊 Progress: 405/2000 (20.2%) | Time: 90.2s | State: running
# 📊 Progress: 429/2000 (21.4%) | Time: 95.2s | State: running
# 📊 Progress: 453/2000 (22.7%) | Time: 100.2s | State: running
# 📊 Progress: 474/2000 (23.7%) | Time: 105.2s | State: running
# 📊 Progress: 497/2000 (24.9%) | Time: 110.2s | State: running
# 📊 Progress: 518/2000 (25.9%) | Time: 115.2s | State: running
# 📊 Progress: 542/2000 (27.1%) | Time: 120.2s | State: running
# 📊 Progress: 561/2000 (28.1%) | Time: 125.2s | State: running
# 📊 Progress: 586/2000 (29.3%) | Time: 130.2s | State: running
# 📊 Progress: 610/2000 (30.5%) | Time: 135.2s | State: running
# 📊 Progress: 630/2000 (31.5%) | Time: 140.2s | State: running
# 📊 Progress: 654/2000 (32.7%) | Time: 145.3s | State: running
# 📊 Progress: 675/2000 (33.8%) | Time: 150.3s | State: running
# 📊 Progress: 698/2000 (34.9%) | Time: 155.3s | State: running
# 📊 Progress: 719/2000 (35.9%) | Time: 160.3s | State: running
# 📊 Progress: 742/2000 (37.1%) | Time: 165.3s | State: running
# 📊 Progress: 765/2000 (38.2%) | Time: 170.3s | State: running
# 📊 Progress: 787/2000 (39.4%) | Time: 175.3s | State: running
# 📊 Progress: 806/2000 (40.3%) | Time: 180.3s | State: running
# 📊 Progress: 829/2000 (41.4%) | Time: 185.3s | State: running
# 📊 Progress: 851/2000 (42.5%) | Time: 190.3s | State: running
# 📊 Progress: 876/2000 (43.8%) | Time: 195.3s | State: running
# 📊 Progress: 897/2000 (44.9%) | Time: 200.4s | State: running
# 📊 Progress: 918/2000 (45.9%) | Time: 205.4s | State: running
# 📊 Progress: 941/2000 (47.0%) | Time: 210.4s | State: running
# 📊 Progress: 962/2000 (48.1%) | Time: 215.4s | State: running
# 📊 Progress: 985/2000 (49.2%) | Time: 220.4s | State: running
# 📊 Progress: 1010/2000 (50.5%) | Time: 225.4s | State: running
# 📊 Progress: 1031/2000 (51.5%) | Time: 230.4s | State: running
# 📊 Progress: 1052/2000 (52.6%) | Time: 235.4s | State: running
# 📊 Progress: 1073/2000 (53.6%) | Time: 240.4s | State: running
# 📊 Progress: 1094/2000 (54.7%) | Time: 245.4s | State: running
# 📊 Progress: 1117/2000 (55.9%) | Time: 250.4s | State: running
# 📊 Progress: 1143/2000 (57.1%) | Time: 255.4s | State: running
# 📊 Progress: 1160/2000 (58.0%) | Time: 260.4s | State: running
# 📊 Progress: 1182/2000 (59.1%) | Time: 265.4s | State: running
# 📊 Progress: 1202/2000 (60.1%) | Time: 270.5s | State: running
# ...
# 🎯 All tasks submitted, waiting for completion...
# 🛑 Stopping experiment...
# 📈 Results: 1989/2000 successful (99.5%)
# ⏱️  Total time: 280.42s
# 📊 Response time stats: avg=1.66s, min=0.56s, max=12.50s
# 📊 Percentiles: P50=1.50s, P95=2.88s, P99=4.08s
# 💾 Saving 1989 request records to experiment_details.csv
# ✅ Successfully saved 1989 detailed records
# ✅ Experiment completed: data_local | dynamic | concurrency=12 | duration=280.42s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | dynamic | concurrency=15
# ============================================================
#
# 🚀 Starting experiment: dynamic | data_local | concurrency=15
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to dynamic
# [2025-06-24 10:52:33,687] Lyt2023/INFO/locust.runners: Ramping to 15 users at a rate of 15.00 per second
# [2025-06-24 10:52:33,690] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 15} (15 total users)
# ✅ Started 15 concurrent users
# 📊 Progress: 50/2000 (2.5%) | Time: 5.0s | State: running
# 📊 Progress: 90/2000 (4.5%) | Time: 10.0s | State: running
# 📊 Progress: 128/2000 (6.4%) | Time: 15.0s | State: running
# 📊 Progress: 168/2000 (8.4%) | Time: 20.0s | State: running
# 📊 Progress: 204/2000 (10.2%) | Time: 25.0s | State: running
# 📊 Progress: 247/2000 (12.3%) | Time: 30.0s | State: running
# 📊 Progress: 285/2000 (14.2%) | Time: 35.0s | State: running
# 📊 Progress: 325/2000 (16.2%) | Time: 40.0s | State: running
# 📊 Progress: 363/2000 (18.1%) | Time: 45.1s | State: running
# 📊 Progress: 400/2000 (20.0%) | Time: 50.1s | State: running
# 📊 Progress: 439/2000 (21.9%) | Time: 55.1s | State: running
# 📊 Progress: 482/2000 (24.1%) | Time: 60.1s | State: running
# 📊 Progress: 528/2000 (26.4%) | Time: 65.1s | State: running
# 📊 Progress: 567/2000 (28.3%) | Time: 70.1s | State: running
# 📊 Progress: 611/2000 (30.6%) | Time: 75.1s | State: running
# 📊 Progress: 655/2000 (32.8%) | Time: 80.1s | State: running
# 📊 Progress: 703/2000 (35.1%) | Time: 85.1s | State: running
# 📊 Progress: 750/2000 (37.5%) | Time: 90.1s | State: running
# 📊 Progress: 790/2000 (39.5%) | Time: 95.1s | State: running
# 📊 Progress: 833/2000 (41.6%) | Time: 100.1s | State: running
# 📊 Progress: 871/2000 (43.5%) | Time: 105.1s | State: running
# 📊 Progress: 917/2000 (45.9%) | Time: 110.1s | State: running
# 📊 Progress: 960/2000 (48.0%) | Time: 115.2s | State: running
# 📊 Progress: 1005/2000 (50.2%) | Time: 120.2s | State: running
# 📊 Progress: 1046/2000 (52.3%) | Time: 125.2s | State: running
# 📊 Progress: 1088/2000 (54.4%) | Time: 130.2s | State: running
# 📊 Progress: 1127/2000 (56.4%) | Time: 135.2s | State: running
# 📊 Progress: 1171/2000 (58.6%) | Time: 140.2s | State: running
# 📊 Progress: 1218/2000 (60.9%) | Time: 145.2s | State: running
# 📊 Progress: 1268/2000 (63.4%) | Time: 150.2s | State: running
# 📊 Progress: 1312/2000 (65.6%) | Time: 155.2s | State: running
# 📊 Progress: 1356/2000 (67.8%) | Time: 160.2s | State: running
# 📊 Progress: 1403/2000 (70.2%) | Time: 165.2s | State: running
# 📊 Progress: 1446/2000 (72.3%) | Time: 170.2s | State: running
# 📊 Progress: 1488/2000 (74.4%) | Time: 175.2s | State: running
# 📊 Progress: 1529/2000 (76.4%) | Time: 180.2s | State: running
# 📊 Progress: 1573/2000 (78.6%) | Time: 185.2s | State: running
# 📊 Progress: 1615/2000 (80.8%) | Time: 190.3s | State: running
# 📊 Progress: 1658/2000 (82.9%) | Time: 195.3s | State: running
# 📊 Progress: 1704/2000 (85.2%) | Time: 200.3s | State: running
# 📊 Progress: 1750/2000 (87.5%) | Time: 205.3s | State: running
# 📊 Progress: 1798/2000 (89.9%) | Time: 210.3s | State: running
# 📊 Progress: 1844/2000 (92.2%) | Time: 215.3s | State: running
# 📊 Progress: 1863/2000 (93.2%) | Time: 220.3s | State: running
# 📊 Progress: 1901/2000 (95.0%) | Time: 225.3s | State: running
# 📊 Progress: 1924/2000 (96.2%) | Time: 230.3s | State: running
# 📊 Progress: 1973/2000 (98.7%) | Time: 235.3s | State: running
# 🎯 Submitting final task (2000/2000)
# ✅ Task limit reached (2000), marking experiment complete
# 📊 Progress: 2000/2000 (100.0%) | Time: 240.4s | State: cleanup
# 🎯 All tasks submitted, waiting for completion...
# 🛑 Stopping experiment...
# 📈 Results: 1986/2000 successful (99.3%)
# ⏱️  Total time: 240.37s
# 📊 Response time stats: avg=1.79s, min=0.55s, max=5.73s
# 📊 Percentiles: P50=1.58s, P95=3.20s, P99=5.04s
# 💾 Saving 1986 request records to experiment_details.csv
# ✅ Successfully saved 1986 detailed records
# ✅ Experiment completed: data_local | dynamic | concurrency=15 | duration=240.37s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | dynamic | concurrency=20
# ============================================================
#
# 🚀 Starting experiment: dynamic | data_local | concurrency=20
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to dynamic
# [2025-06-24 10:57:09,568] Lyt2023/INFO/locust.runners: Ramping to 20 users at a rate of 20.00 per second
# [2025-06-24 10:57:09,571] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 20} (20 total users)
# ✅ Started 20 concurrent users
# 📊 Progress: 58/2000 (2.9%) | Time: 5.0s | State: running
# 📊 Progress: 78/2000 (3.9%) | Time: 10.0s | State: running
# 📊 Progress: 119/2000 (5.9%) | Time: 15.0s | State: running
# 📊 Progress: 162/2000 (8.1%) | Time: 20.0s | State: running
# 📊 Progress: 206/2000 (10.3%) | Time: 25.0s | State: running
# 📊 Progress: 253/2000 (12.7%) | Time: 30.0s | State: running
# 📊 Progress: 303/2000 (15.2%) | Time: 35.0s | State: running
# 📊 Progress: 356/2000 (17.8%) | Time: 40.0s | State: running
# 📊 Progress: 401/2000 (20.1%) | Time: 45.1s | State: running
# 📊 Progress: 456/2000 (22.8%) | Time: 50.1s | State: running
# 📊 Progress: 504/2000 (25.2%) | Time: 55.1s | State: running
# 📊 Progress: 525/2000 (26.2%) | Time: 60.1s | State: running
# 📊 Progress: 571/2000 (28.5%) | Time: 65.1s | State: running
# 📊 Progress: 620/2000 (31.0%) | Time: 70.1s | State: running
# 📊 Progress: 672/2000 (33.6%) | Time: 75.1s | State: running
# 📊 Progress: 726/2000 (36.3%) | Time: 80.1s | State: running
# 📊 Progress: 776/2000 (38.8%) | Time: 85.1s | State: running
# 📊 Progress: 821/2000 (41.0%) | Time: 90.1s | State: running
# 📊 Progress: 869/2000 (43.5%) | Time: 95.1s | State: running
# 📊 Progress: 920/2000 (46.0%) | Time: 100.1s | State: running
# 📊 Progress: 970/2000 (48.5%) | Time: 105.1s | State: running
# 📊 Progress: 1016/2000 (50.8%) | Time: 110.1s | State: running
# 📊 Progress: 1050/2000 (52.5%) | Time: 115.2s | State: running
# 📊 Progress: 1101/2000 (55.0%) | Time: 120.2s | State: running
# 📊 Progress: 1154/2000 (57.7%) | Time: 125.2s | State: running
# 📊 Progress: 1200/2000 (60.0%) | Time: 130.2s | State: running
# 📊 Progress: 1249/2000 (62.5%) | Time: 135.2s | State: running
# 📊 Progress: 1303/2000 (65.1%) | Time: 140.2s | State: running
# 📊 Progress: 1356/2000 (67.8%) | Time: 145.2s | State: running
# 📊 Progress: 1400/2000 (70.0%) | Time: 150.2s | State: running
# 📊 Progress: 1452/2000 (72.6%) | Time: 155.2s | State: running
# 📊 Progress: 1505/2000 (75.2%) | Time: 160.2s | State: running
# 📊 Progress: 1558/2000 (77.9%) | Time: 165.2s | State: running
# 📊 Progress: 1608/2000 (80.4%) | Time: 170.2s | State: running
# 📊 Progress: 1659/2000 (83.0%) | Time: 175.2s | State: running
# 📊 Progress: 1714/2000 (85.7%) | Time: 180.2s | State: running
# 📊 Progress: 1765/2000 (88.2%) | Time: 185.2s | State: running
# 📊 Progress: 1825/2000 (91.2%) | Time: 190.2s | State: running
# 📊 Progress: 1872/2000 (93.6%) | Time: 195.2s | State: running
# 📊 Progress: 1925/2000 (96.2%) | Time: 200.3s | State: running
# 📊 Progress: 1978/2000 (98.9%) | Time: 205.3s | State: running
# 🎯 Submitting final task (2000/2000)
# ✅ Task limit reached (2000), marking experiment complete
# 📊 Progress: 2000/2000 (100.0%) | Time: 210.3s | State: cleanup
# 🎯 All tasks submitted, waiting for completion...
# 🛑 Stopping experiment...
# 📈 Results: 1981/2000 successful (99.1%)
# ⏱️  Total time: 210.28s
# 📊 Response time stats: avg=2.08s, min=0.55s, max=12.70s
# 📊 Percentiles: P50=1.91s, P95=3.83s, P99=6.90s
# 💾 Saving 1981 request records to experiment_details.csv
# ✅ Successfully saved 1981 detailed records
# ✅ Experiment completed: data_local | dynamic | concurrency=20 | duration=210.28s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | dynamic | concurrency=30
# ============================================================
#
# 🚀 Starting experiment: dynamic | data_local | concurrency=30
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to dynamic
# [2025-06-24 11:01:15,374] Lyt2023/INFO/locust.runners: Ramping to 30 users at a rate of 30.00 per second
# [2025-06-24 11:01:15,378] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 30} (30 total users)
# ✅ Started 30 concurrent users
# 📊 Progress: 58/2000 (2.9%) | Time: 5.0s | State: running
# 📊 Progress: 109/2000 (5.5%) | Time: 10.0s | State: running
# 📊 Progress: 148/2000 (7.4%) | Time: 15.0s | State: running
# 📊 Progress: 202/2000 (10.1%) | Time: 20.0s | State: running
# 📊 Progress: 259/2000 (13.0%) | Time: 25.0s | State: running
# 📊 Progress: 314/2000 (15.7%) | Time: 30.0s | State: running
# 📊 Progress: 376/2000 (18.8%) | Time: 35.0s | State: running
# 📊 Progress: 446/2000 (22.3%) | Time: 40.0s | State: running
# 📊 Progress: 503/2000 (25.1%) | Time: 45.0s | State: running
# 📊 Progress: 560/2000 (28.0%) | Time: 50.0s | State: running
# 📊 Progress: 620/2000 (31.0%) | Time: 55.1s | State: running
# 📊 Progress: 674/2000 (33.7%) | Time: 60.1s | State: running
# 📊 Progress: 725/2000 (36.2%) | Time: 65.1s | State: running
# 📊 Progress: 792/2000 (39.6%) | Time: 70.1s | State: running
# 📊 Progress: 854/2000 (42.7%) | Time: 75.1s | State: running
# 📊 Progress: 916/2000 (45.8%) | Time: 80.1s | State: running
# 📊 Progress: 981/2000 (49.0%) | Time: 85.1s | State: running
# 📊 Progress: 1044/2000 (52.2%) | Time: 90.1s | State: running
# 📊 Progress: 1108/2000 (55.4%) | Time: 95.1s | State: running
# 📊 Progress: 1174/2000 (58.7%) | Time: 100.1s | State: running
# 📊 Progress: 1236/2000 (61.8%) | Time: 105.1s | State: running
# 📊 Progress: 1303/2000 (65.1%) | Time: 110.1s | State: running
# 📊 Progress: 1368/2000 (68.4%) | Time: 115.1s | State: running
# 📊 Progress: 1434/2000 (71.7%) | Time: 120.1s | State: running
# 📊 Progress: 1497/2000 (74.9%) | Time: 125.1s | State: running
# 📊 Progress: 1556/2000 (77.8%) | Time: 130.1s | State: running
# 📊 Progress: 1613/2000 (80.7%) | Time: 135.2s | State: running
# 📊 Progress: 1679/2000 (84.0%) | Time: 140.2s | State: running
# 📊 Progress: 1725/2000 (86.2%) | Time: 145.2s | State: running
# 📊 Progress: 1791/2000 (89.5%) | Time: 150.2s | State: running
# 📊 Progress: 1850/2000 (92.5%) | Time: 155.2s | State: running
# 📊 Progress: 1920/2000 (96.0%) | Time: 160.2s | State: running
# 📊 Progress: 1977/2000 (98.9%) | Time: 165.2s | State: running
# 🎯 Submitting final task (2000/2000)
# ✅ Task limit reached (2000), marking experiment complete
# 📊 Progress: 2000/2000 (100.0%) | Time: 170.2s | State: cleanup
# 🎯 All tasks submitted, waiting for completion...
# 🛑 Stopping experiment...
# 📈 Results: 1971/2000 successful (98.6%)
# ⏱️  Total time: 170.20s
# 📊 Response time stats: avg=2.52s, min=0.58s, max=16.94s
# 📊 Percentiles: P50=2.54s, P95=4.70s, P99=6.73s
# 💾 Saving 1971 request records to experiment_details.csv
# ✅ Successfully saved 1971 detailed records
# ✅ Experiment completed: data_local | dynamic | concurrency=30 | duration=170.20s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🔬 Running: data_local | dynamic | concurrency=40
# ============================================================
#
# 🚀 Starting experiment: dynamic | data_local | concurrency=40
# [✓] Reloaded http://yl-01.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-02.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-03.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-04.lab.uvalight.net:31113 to dynamic
# [✓] Reloaded http://yl-06.lab.uvalight.net:31113 to dynamic
# [2025-06-24 11:04:41,127] Lyt2023/INFO/locust.runners: Ramping to 40 users at a rate of 40.00 per second
# [2025-06-24 11:04:41,132] Lyt2023/INFO/locust.runners: All users spawned: {"FaaSUser": 40} (40 total users)
# ✅ Started 40 concurrent users
# 📊 Progress: 59/2000 (2.9%) | Time: 5.0s | State: running
# 📊 Progress: 110/2000 (5.5%) | Time: 10.0s | State: running
# 📊 Progress: 187/2000 (9.3%) | Time: 15.0s | State: running
# 📊 Progress: 245/2000 (12.2%) | Time: 20.0s | State: running
# 📊 Progress: 294/2000 (14.7%) | Time: 25.0s | State: running
# 📊 Progress: 352/2000 (17.6%) | Time: 30.0s | State: running
# 📊 Progress: 414/2000 (20.7%) | Time: 35.0s | State: running
# 📊 Progress: 486/2000 (24.3%) | Time: 40.0s | State: running
# 📊 Progress: 556/2000 (27.8%) | Time: 45.1s | State: running
# 📊 Progress: 627/2000 (31.4%) | Time: 50.1s | State: running
# 📊 Progress: 699/2000 (34.9%) | Time: 55.1s | State: running
# 📊 Progress: 772/2000 (38.6%) | Time: 60.1s | State: running
# 📊 Progress: 846/2000 (42.3%) | Time: 65.1s | State: running
# 📊 Progress: 906/2000 (45.3%) | Time: 70.1s | State: running
# 📊 Progress: 980/2000 (49.0%) | Time: 75.1s | State: running
# 📊 Progress: 1041/2000 (52.0%) | Time: 80.1s | State: running
# 📊 Progress: 1107/2000 (55.4%) | Time: 85.1s | State: running
# 📊 Progress: 1166/2000 (58.3%) | Time: 90.1s | State: running
# 📊 Progress: 1229/2000 (61.5%) | Time: 95.1s | State: running
# 📊 Progress: 1294/2000 (64.7%) | Time: 100.1s | State: running
# 📊 Progress: 1353/2000 (67.7%) | Time: 105.1s | State: running
# 📊 Progress: 1420/2000 (71.0%) | Time: 110.1s | State: running
# 📊 Progress: 1490/2000 (74.5%) | Time: 115.1s | State: running
# 📊 Progress: 1553/2000 (77.6%) | Time: 120.2s | State: running
# 📊 Progress: 1623/2000 (81.2%) | Time: 125.2s | State: running
# 📊 Progress: 1692/2000 (84.6%) | Time: 130.2s | State: running
# 📊 Progress: 1754/2000 (87.7%) | Time: 135.2s | State: running
# 📊 Progress: 1821/2000 (91.0%) | Time: 140.2s | State: running
# 📊 Progress: 1885/2000 (94.2%) | Time: 145.2s | State: running
# 📊 Progress: 1944/2000 (97.2%) | Time: 150.2s | State: running
# 🎯 Submitting final task (2000/2000)
# 📊 Progress: 2000/2000 (100.0%) | Time: 155.2s | State: running
# 🎯 All tasks submitted, waiting for completion...
# ✅ Task limit reached (2000), marking experiment complete
# 📊 Progress: 2000/2000 (100.0%) | Time: 160.2s | State: stopped
# 🛑 Stopping experiment...
# 📈 Results: 1962/2000 successful (98.1%)
# ⏱️  Total time: 160.21s
# 📊 Response time stats: avg=3.11s, min=0.59s, max=17.26s
# 📊 Percentiles: P50=2.81s, P95=6.89s, P99=8.40s
# 💾 Saving 1962 request records to experiment_details.csv
# ✅ Successfully saved 1962 detailed records
# ✅ Experiment completed: data_local | dynamic | concurrency=40 | duration=160.21s
# 😴 Cooling down for 30s...
#
# ============================================================
# 🎊 ALL EXPERIMENTS COMPLETED!
# ============================================================
# ✅ All experiments completed successfully!
# 📊 Summary results saved to: experiment_summary.csv
# 📊 Detailed results saved to: experiment_details.csv
#
# 📈 Overall Statistics:
#    Total requests: 79455
#    Successful requests: 79455
#    Overall success rate: 100.0%
#    Average response time: 1.832s
#
# 📊 Statistics by function type:
#    data_local: 79455 requests, avg=1.832s
# D:\ProgramData\anaconda3\envs\sionna\lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:
